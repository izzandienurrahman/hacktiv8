# %%
import pandas as pd
import sys

# %%
datasetdir = "/Users/izzan/Documents/Datasets/Global Air Transportation Network"
dataset = "/airlines.csv"
csv_airports = "/airports.csv"
csv_airplanes = "/airplanes.csv"
csv_airlines = "/airlines.csv"
csv_routes = "/routes.csv"

# %%
sys.path.append(datasetdir)

# %%
sys.path
# Out:
# ['/Users/izzan/Documents/hacktiv8/MilestonePractice',
#  '/Users/izzan/.vscode/extensions/ms-toolsai.jupyter-2022.11.1003412109/pythonFiles',
#  '/Users/izzan/.vscode/extensions/ms-toolsai.jupyter-2022.11.1003412109/pythonFiles/lib/python',
#  '/opt/homebrew/anaconda3/lib/python39.zip',
#  '/opt/homebrew/anaconda3/lib/python3.9',
#  '/opt/homebrew/anaconda3/lib/python3.9/lib-dynload',
#  '',
#  '/opt/homebrew/anaconda3/lib/python3.9/site-packages',
#  '/opt/homebrew/anaconda3/lib/python3.9/site-packages/aeosa',
#  '/Users/izzan/Documents/Datasets/Global Air Transportation Network']

# %%
df_airports = pd.read_csv(datasetdir+csv_airports)
df_airlines = pd.read_csv(datasetdir+csv_airlines)
df_airplanes = pd.read_csv(datasetdir+csv_airplanes)
df_routes = pd.read_csv(datasetdir+csv_routes)

# %%
df_airports.head()
# Out:
#    index  Airport ID                                         Name  \
# 0      0           1                               Goroka Airport
# 1      1           2                               Madang Airport
# 2      2           3                 Mount Hagen Kagamuga Airport
# 3      3           4                               Nadzab Airport
# 4      4           5  Port Moresby Jacksons International Airport
#
#            City           Country IATA  ICAO  Latitude   Longitude  Altitude  \
# 0        Goroka  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282
# 1        Madang  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20
# 2   Mount Hagen  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388
# 3        Nadzab  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239
# 4  Port Moresby  Papua New Guinea  POM  AYPY -9.443380  147.220001       146
#
#   Timezone DST Tz database time zone     Type       Source
# ...

# %%
df_airlines.head()
# Out:
#    index  Airline ID                                          Name Alias IATA  \
# 0      0          -1                                       Unknown    \N    -
# 1      1           1                                Private flight    \N    -
# 2      2           2                                   135 Airways    \N  NaN
# 3      3           3                                 1Time Airline    \N   1T
# 4      4           4  2 Sqn No 1 Elementary Flying Training School    \N  NaN
#
#   ICAO Callsign         Country Active
# 0  NaN       \N              \N      Y
# 1  NaN      NaN             NaN      Y
# 2  GNL  GENERAL   United States      N
# 3  RNX  NEXTIME    South Africa      Y
# 4  WYT      NaN  United Kingdom      N

# %%
df_airplanes.head()
# Out:
#    index                                          Name IATA code ICAO code
# 0      0                       Aerospatiale (Nord) 262       ND2      N262
# 1      1  Aerospatiale (Sud Aviation) Se.210 Caravelle       CRV      S210
# 2      2                  Aerospatiale SN.601 Corvette       NDC      S601
# 3      3                Aerospatiale/Alenia ATR 42-300       AT4      AT43
# 4      4                Aerospatiale/Alenia ATR 42-500       AT5      AT45

# %%
df_routes.head()
# Out:
#    index Airline Airline ID Source airport Source airport ID  \
# 0      0      2B        410            AER              2965
# 1      1      2B        410            ASF              2966
# 2      2      2B        410            ASF              2966
# 3      3      2B        410            CEK              2968
# 4      4      2B        410            CEK              2968
#
#   Destination airport Destination airport ID Codeshare  Stops Equipment
# 0                 KZN                   2990       NaN      0       CR2
# 1                 KZN                   2990       NaN      0       CR2
# 2                 MRV                   2962       NaN      0       CR2
# 3                 KZN                   2990       NaN      0       CR2
# 4                 OVB                   4078       NaN      0       CR2

# %%
df_airports[df_airports['IATA']=='GKA']
# Out:
#    index  Airport ID            Name    City           Country IATA  ICAO  \
# 0      0           1  Goroka Airport  Goroka  Papua New Guinea  GKA  AYGA
#
#    Latitude   Longitude  Altitude Timezone DST Tz database time zone     Type  \
# 0  -6.08169  145.391998      5282       10   U  Pacific/Port_Moresby  airport
#
#         Source
# 0  OurAirports

# %%
df_airplanes[df_airplanes['IATA code']=='GKA']
# Out:
# Empty DataFrame
# Columns: [index, Name, IATA code, ICAO code]
# Index: []
